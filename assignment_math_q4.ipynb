# %% [markdown]
# <a href="https://colab.research.google.com/github/Louis123-b/Practical-Discrete-Mathematics/blob/master/assignment_math_q4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q4. You are tasked with creating a decision tree classifier to sort new students into one of the four Hogwarts houses: Gryffindor, Hufflepuff, Ravenclaw or Slytherin. The dataset contains various attributes of students such as bravery, loyalty, intelligence, and ambition. Dataset: The dataset is provided in a CSV file named hogwarts_students.csv with the following columns:
#
# • Bravery: a score from 1 to 10 indicating the student’s bravery.
#
# • Loyalty: a score from 1 to 10 indicating the student’s loyalty.
#
# • Intelligence: a score from 1 to 10 indicating the student’s intelligence
#
# • Ambition: a score from 1 to 10 indicating the student’s ambition.
#
# • House: the house the student belongs to Gryffindor, Hufflepuff, Ravenclaw or Slytherin Tasks:
# a. Data loading and preprocessing
#
# • Load the dataset from the CSV file

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('hogwarts_students.csv')
print(df.head())
# Out:
#    Bravery  Loyalty  Intelligence  Ambition       House
# 0      8.0      6.0           7.0       5.0  Gryffindor
# 1      4.0      9.0           6.0       3.0  Hufflepuff
# 2      5.0      5.0           9.0       4.0   Ravenclaw
# 3      3.0      4.0           5.0       8.0   Slytherin
# 4      7.0      8.0           NaN       6.0  Gryffindor

# %% [markdown]
# • Handle any missing values if present

# %%
import pandas as pd

# Load the dataset
file_path = '/content/hogwarts_students.csv'  # Update the path if necessary
df = pd.read_csv(file_path)

# Check for missing values
print("\nMissing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# Bravery         3
# Loyalty         2
# Intelligence    1
# Ambition        3
# House           0
# dtype: int64

# %% [markdown]
# b) Feature Selection and Splitting

# %%
# Features
X = df[['Bravery', 'Loyalty', 'Intelligence', 'Ambition']]
# Target variable
y = df['House']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# c) Model Training

# %%
from sklearn.tree import DecisionTreeClassifier

# Initialize the classifier
clf = DecisionTreeClassifier(random_state=42)

# Train the classifier
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# d) Model Evaluation with Chart

# %%
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Predictions
y_pred = clf.predict(X_test)

# Evaluation metrics
print(classification_report(y_test, y_pred))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=clf.classes_, yticklabels=clf.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#   Gryffindor       1.00      1.00      1.00         4
#   Hufflepuff       1.00      1.00      1.00         4
#    Ravenclaw       1.00      1.00      1.00         1
#    Slytherin       1.00      1.00      1.00         1
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10

# %% [markdown]
# e) Prediction

# %%
# Example new student data
new_students = pd.DataFrame({
    'Bravery': [8, 5],
    'Loyalty': [6, 9],
    'Intelligence': [7, 4],
    'Ambition': [5, 8]
})

# Predict the house for new students
predictions = clf.predict(new_students)
print(predictions)
# Out:
# ['Gryffindor' 'Hufflepuff']
